# %% [markdown]
# # Workshop_08

# %% [markdown]
# # Problem 1
#
# Flask에서 Dictionary 자료형을 이용하여 다음 조건을 만족하는 ‘나만의 영어 단어장’
# 페이지를 만들어보세요.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 실행 결과
# 1. 단어가 있는 경우
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 단어가 없는 경우
# ![image.png](attachment:image.png)

# %%
# 정답
